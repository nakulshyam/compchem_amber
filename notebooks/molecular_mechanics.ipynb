# %%
run ../scripts/molecular_mechanics/mm.py ../geom/prm/ethane.prm
# Out:
# -------- Energy Values --------
#    component         [kcal/mol]
# -------------------------------
#    Total         |     0.2846
#    Kinetic       |     0.0000
#    Potential     |     0.2846
#    Non-bonded    |     0.0000
#    Bonded        |     0.2846
#    Boundary      |     0.0000
#    van der Waals |     0.0000
#    Electrostatic |     0.0000
#    Bonds         |     0.0956
#    Angles        |     0.1886
#    Torsions      |     0.0004
#    Out-of-planes |     0.0000
#
# -------- Molecular Geometry and Non-bonded Parameters ---------
#       type     x         y         z       q      ro/2    eps
# ---------------------------------------------------------------
#    1 | CT   -5.7154    2.8978    0.2542 -0.6300  1.9080  0.1094
#    2 | CT   -4.5451    2.2596   -0.4587 -0.6300  1.9080  0.1094
#    3 | HC   -5.3676    3.6596    0.9583  0.2100  1.4870  0.0157
#    4 | HC   -6.2815    2.1464    0.8124  0.2100  1.4870  0.0157
# ...
