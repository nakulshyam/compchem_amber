# %%
run ../scripts/geometry_analysis/bonds.py ../geom/xyz/
# Out:
# 10
# initial geometry
# C     -1.146880     1.651330    -1.426920
# O     -2.339480     1.409070    -1.247850
# C     -0.434100     1.223060    -2.681060
# C     -0.329140     2.390490    -0.402580
# H     -1.131280     0.699450    -3.341030
# H      0.384880     0.546770    -2.424110
# H     -0.047950     2.102910    -3.201500
# H     -0.956350     2.645080     0.456240
# H      0.060790     3.312350    -0.841040
# H      0.493620     1.756210    -0.063650
#
# bond graph
#     1 C  - 2 3 4
#     2 O  - 1
#     3 C  - 1 5 6 7
#     4 C  - 1 8 9 10
#     5 H  - 3
#     6 H  - 3
#     7 H  - 3
#     8 H  - 4
#     9 H  - 4
#    10 H  - 4
#
# 9 bond(s) found (Angstrom)
#  1-2              (C-O)            1.2301
#  1-3              (C-C)            1.5048
#  1-4              (C-C)            1.5048
#  3-5              (C-H)            1.0935
#  3-6              (C-H)            1.0928
#  3-7              (C-H)            1.0928
#  4-8              (C-H)            1.0935
# ...

# %%
run ../scripts/geometry_analysis/angles.py ../geom/xyz/h2o.xyz
# Out:
# 3
# initial geometry
# O      0.538900     0.655660     0.000000
# H      1.508900     0.655660     0.000000
# H      0.215570     1.569690    -0.030130
#
# 2 bond(s) found (Angstrom)
#  1-2              (O-H)            0.9700
#  1-3              (O-H)            0.9700
#
# 1 angle(s) found (degrees)
#  2-1-3            (H-O-H)         109.471

# %%
run ../scripts/geometry_analysis/torsions.py ../geom/xyz/hooh.xyz
# Out:
# 4
# initial geometry
# O     -1.752880    -0.518770     1.332360
# O     -0.473700    -0.109130     0.777370
# H     -2.290180     0.167830     0.893290
# H      0.063600    -0.795730     1.216440
#
# 3 bond(s) found (Angstrom)
#  1-2              (O-O)            1.4533
#  1-3              (O-H)            0.9762
#  2-4              (O-H)            0.9762
#
# 2 angle(s) found (degrees)
#  2-1-3            (O-O-H)          96.572
#  1-2-4            (O-O-H)          96.572
#
# 1 torsion(s) found (degrees)
#  3-1-2-4          (H-O-O-H)      -180.000

# %%
run ../scripts/geometry_analysis/out_of_planes.py ../geom/xyz/ethane.xyz
# Out:
# 8
# initial geometry
# C     -0.023970     0.184840    -0.104300
# C     -0.256210    -0.727030    -1.287890
# H      0.849540    -0.142400     0.467460
# H     -0.892620     0.180080     0.560860
# H      0.148290     1.212260    -0.438620
# H     -0.428470    -1.754450    -0.953570
# H      0.612440    -0.722270    -1.953050
# H     -1.129720    -0.399790    -1.859660
#
# 7 bond(s) found (Angstrom)
#  1-2              (C-C)            1.5121
#  1-3              (C-H)            1.0941
#  1-4              (C-H)            1.0941
#  1-5              (C-H)            1.0941
#  2-6              (C-H)            1.0941
#  2-7              (C-H)            1.0941
#  2-8              (C-H)            1.0941
#
# 12 angle(s) found (degrees)
#  2-1-3            (C-C-H)         110.568
#  2-1-4            (C-C-H)         110.568
#  2-1-5            (C-C-H)         110.567
#  3-1-4            (H-C-H)         108.353
#  3-1-5            (H-C-H)         108.352
# ...

# %%
run ../scripts/geometry_analysis/center_of_mass.py ../geom/xyz/adamantane.xyz
# Out:
# 26
# initial geometry
# C     -1.424710     0.500320     0.586740
# C     -0.065600    -0.132500     0.239710
# C      0.923000     0.978820    -0.154910
# C      0.388180     1.754290    -1.371750
# C     -0.973510     2.376410    -1.015580
# C     -1.972910     1.273060    -0.625870
# H     -1.359480     2.946520    -1.869560
# H     -0.856000     3.084960    -0.186480
# H     -1.314920     1.176760     1.443270
# H     -2.135420    -0.279820     0.885980
# C     -2.141300     0.303280    -1.808760
# H      1.901970     0.543060    -0.389450
# C     -0.244790    -1.094320    -0.948090
# C      0.206410     0.781780    -2.550410
# H      1.072960     1.663450     0.688920
# H      0.319950    -0.681170     1.106150
# H      1.095580     2.543910    -1.648310
# H     -2.940220     1.721340    -0.373380
# C     -0.786270    -0.330660    -2.169440
# H      1.173110     0.342650    -2.825940
# H     -0.159370     1.324600    -3.430650
# H     -0.935310    -1.901740    -0.675110
# ...

# %%
run ../scripts/geometry_analysis/moment_of_inertia.py ../geom/xyz/12difluoroethane.xyz
# Out:
# 8
# initial geometry
# C     -0.533710    -1.062760     0.152360
# C      0.315650    -2.236180     0.579520
# F      0.263190     0.016050    -0.067500
# F     -0.481240    -3.315000     0.799380
# H     -1.078150    -1.286390    -0.769500
# H     -1.263750    -0.804030     0.924600
# H      1.045700    -2.494910    -0.192710
# H      0.860090    -2.012560     1.501390
#
# 7 bond(s) found (Angstrom)
#  1-2              (C-C)            1.5102
#  1-3              (C-F)            1.3591
#  1-5              (C-H)            1.0937
#  1-6              (C-H)            1.0937
#  2-4              (C-F)            1.3591
#  2-7              (C-H)            1.0937
#  2-8              (C-H)            1.0937
#
# 12 angle(s) found (degrees)
#  2-1-3            (C-C-F)         109.435
#  2-1-5            (C-C-H)         111.069
#  2-1-6            (C-C-H)         111.069
#  3-1-5            (F-C-H)         108.531
#  3-1-6            (F-C-H)         108.531
# ...

# %%
run ../scripts/geometry_analysis/geometry_analysis.py ../geom/xyz/benzene.xyz
# Out:
# geometry analysis for benzene
#
# 12
# initial geometry
# C     -0.268570    -0.461670    -1.431230
# C      0.013080     0.053910    -0.166160
# C     -0.240010    -0.712450     0.971460
# C     -0.774740    -1.994390     0.844020
# C     -1.056380    -2.509970    -0.421040
# C     -0.803300    -1.743610    -1.558670
# H     -1.022740    -2.145310    -2.544300
# H     -0.071390     0.135410    -2.317560
# H      0.429690     1.052680    -0.066870
# H     -0.020570    -0.310750     1.957100
# H     -0.971920    -2.591470     1.730360
# H     -1.473000    -3.508740    -0.520340
#
# 12 bond length(s) found (Angstrom)
#  atoms            elements         values
#  1-2              (C-C)            1.3948
#  1-6              (C-C)            1.3948
#  1-8              (C-H)            1.0867
#  2-3              (C-C)            1.3948
#  2-9              (C-H)            1.0867
#  3-4              (C-C)            1.3948
#  3-10             (C-H)            1.0867
# ...
